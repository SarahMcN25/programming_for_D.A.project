# %% [markdown]
# ![covid](https://www.bandondental.ie/uploads/LTClELt1/banner.png)

# %% [markdown]
# # An Investigation into the Coronavirus in the European Union
# https://ourworldindata.org/coronavirus#coronavirus-country-profiles
# ***

# %% [markdown]
# # Introduction
# ***

# %% [markdown]
# There are 27 member states in the [European Union](https://en.wikipedia.org/wiki/Demographics_of_the_European_Union) (EU) as of Dec 2021. In this notebook I will:
#
#
# 1. Investigate 4 variables of the Coronavirus Pandemic within the EU.
#
#
# 2. Simulate data to represent how these variables have affected countries in the EU.

# %% [markdown]
# # references for end
#
#
#
#
# https://ourworldindata.org/covid-vaccinations
#
#
# https://www.worldometers.info/population/countries-in-the-eu-by-population/

# %% [markdown]
# # The European Centre for Disease Prevention and Control
# ***

# %% [markdown]
# The [European Centre for Disease Prevention and Control](https://www.ecdc.europa.eu/en/covid-19/timeline-ecdc-response) (ECDC) is an agency of the European Union. It's mission is "to identify, assess and communicates current and emerging threats to human health posed by infectious disease".
#
#
# The ECDC website has an impressive interactive timeline of the main ECDC implementations and developments of the virus from the beginning of the cornoavirus pandemic. It can be found [here](https://cdn.knightlab.com/libs/timeline3/latest/embed/index.html?source=1JplnWBhopqsH40JLp1mppywwgAZAZgohFy7aELWaSPg&font=Default&lang=en&initial_zoom=2&height=650).

# %% [markdown]
# # Timeline Highlights to date
# https://www.ecdc.europa.eu/en/covid-19/timeline-ecdc-response
# ***

# %% [markdown]
# #### Here are some of the main developments:
#
# <br>
#
# **January 24th 2020**
# First EU country to report a case. This was in France with a direct link to China.
#
#
# **January 28th 2020**
# Cases reported in Germany.
#
#
# **January 20th 2020**
# World Health Organization (WHO) declares internaitonal public health emergency.
#
#
# **February 22nd 2020**
# Outbreak reported in Italy.
#
#
# **February 24th 2020**
# WHO and ECDC launch a joint effort for control and prevention of covid-19 in Italy.
#
#
# **February 29th 2020**
# First confirmed case of covid-19 in Ireland.
#
#
# **March 8th 2020**
# Italy imposes strict public health measures in affected regions.
#
#
# **March 11th 2020**
# Some EU countries imposes public health measures at a national level.
#
#
# **March 11th 2020**
# WHO declares covid-19 a global pandemic.
#
#
# **April 9th 2020**
# ECDC issues documnet on contact tracing.
#
#
# **April 14th 2020**
# ECDC issues information on face mask use in the community.
# EU commission publishes roadmap to lift covid-19 containment measures in Europe.
#
#
# **May 5th 2020**
# ECDC publishes documnet outline resource measures for contract tracing.
#
#
# **May 13th 2020**
# EU commission produces guidelines for lifting travel restrictions.
#
#
# **June 17th 2020**
# EU commission presets strategy for development and manfacturing of covid-19 vaccines.
#
#
# **September 16th 2020**
# Increase in cases across Europe.
#
#
# **September 23rd 2020**
# ECDC launches new covid-19 situation dashboard which can be found [here](https://qap.ecdc.europa.eu/public/extensions/COVID-19/COVID-19.html#global-overview-tab).
#
#
# **December 21st 2020**
# First covid-19 vaccine authorised for use in the EU.
#
#
# **December 22nd 2020**
# ECDC releases covid-19 vaccination rollout strategies for EU.
#
#
# **January 21st 2021**
# The ECDC and Joint Research Centre (JRC) launch a joint database on response measures. You can access this database [here](https://covid-statistics.jrc.ec.europa.eu/QlikDashboard?sheet=multidim).
#
#
# **February 1st 2021**
# ECDC launchs vaccination dashboard. This can be found [here](https://qap.ecdc.europa.eu/public/extensions/COVID-19/COVID-19.html#global-overview-tab).
#
#
# **February 4th 2021**
# The number of confirmed cases worldwide surpasses 100 million.
#
#
# **February 18th 2021**
# ECDC launches a vaccination tracker which reports weeking updates. This can be found [here](https://vaccinetracker.ecdc.europa.eu/public/extensions/COVID-19/vaccine-tracker.html#uptake-tab)
#
#
# **April 22nd 2021**
# A new forcasting dashboard to suppor the EU planning for the pandemic. It cna be found [here](https://covid19forecasthub.eu/visualisation.html).
#
#
# **June 29th 2021**
# ECDC launches report on "countering online vaccine misinformaiton in the EU"
#
#
# **July 14th 2021**
# European Medinces Agency (EMA) and the ECDC urge EU citizens to get vaccinated.
#
#
# **August 4th 2021**
# Further push by EMA and ECDC for EU citizens to get vaccinated.
#
#
# **September 2nd 2021**
# ECDC and EMA highlight recommendations for additional booster does of covid-19 vaccines.
#
#
# **September 3rd 2021**
# ECDC awards 77 million to EU member states to aid with detection of covid-19 within each countries' national public health programmes.
#
#
# **September 30th 2021**
# ECDC reports surge in covid-19 cases and deaths in countries with insufficent vaccination coverage.
#
#
# **October 8th 2021**
# ECDC builds study for monitor vaccine effectiveness.
#
#
# **October 15th 2021**
# ECDC aids member states to increase uptake of vaccines.
#
#
# **November 24th 2021**
# ECDC urges public health measures to be applied due to high rish of covid-19 rise.
#
#
# **November 25th 2021**
# New study published by WHO and ECDC estimates nearly half a million lives have been saved by covid-19 vaccination in less than a year.
#
#
# **December 7th 2021**
# EMA and ECDC recommend heterlogous (mix-and-match) vaccination courses againt covid-19.
#
# <br>

# %% [markdown]
# # Covid-19 Varients
# ***

# %% [markdown]
# There is an interesting blog by John Hopkins Medicine found [here](https://www.hopkinsmedicine.org/health/conditions-and-diseases/coronavirus) which explains what that coronaviruses are a type of virus of which there are many. However, covid-19 which was identified in 2019 in Wuhan, China is quite a severe virus which is the reason it has casued a worldwide pandemic. This blog continues to explain that covid-19 likely origionated in an aminal which may cause harm to humans. Moreover, this blog describes that all viruses mutate resulting in new varients of that virus.

# %% [markdown]
# Covid-19 is no different from any other virus in terms of mutation. WHO is tracking covid-19 varients since the beginning of the pandemic. This image below was taken from their webpage found [here](https://www.who.int/en/activities/tracking-SARS-CoV-2-variants/)

# %% [markdown]
# <img src="img/who_varients.png" width="900"/>

# %% [markdown]
# This table shows us the main varients of concern for the WHO. We can see when and where these varients were first documented. This information may be a factor when considering the timeline of confirmed covid-19 cases and deaths.
#
# <br>

# %% [markdown]
# # Variables
# ***

# %% [markdown]
# There is a website called "ourworldindata.org" which has an impressive interactive explorer with coronavirus data. It can be found [here](https://ourworldindata.org/explorers/coronavirus-data-explorer?facet=none&pickerSort=asc&pickerMetric=location&Metric=People+fully+vaccinated&Interval=7-day+rolling+average&Relative+to+Population=true&Align+outbreaks=false&country=AUT~BEL~BGR~HRV~CYP~CZE~DNK~EST~FIN~FRA~DEU~GRC~HUN~IRL~ITA~LVA~LTU~LUX~MLT~NLD~POL~PRT~ROU~SVK~SVN~ESP~SWE). This explorer displays a chart, map, table sources and downloadable material relating to covid-19. There are numerous variable which can be selected. Users can filter the variables by country and intervels. I have captured images from this website which will be displayed below in order to visualise covid-19 data relating to confirmed cases, confirmed deaths, people fully vaccinated, partially vaccinated and unvaccinated.

# %% [markdown]
# ## Reported cases

# %% [markdown]
# Taking a look at the 27 member states of the EU, the following chart displays the cumulative confirmed cases of covid-19 from the beginning of the pandemic. This chart was taken from the our world in data [webpage](https://ourworldindata.org/explorers/coronavirus-data-explorer?time=earliest..2021-12-16&facet=none&uniformYAxis=0&pickerSort=asc&pickerMetric=location&Metric=Confirmed+cases&Interval=Cumulative&Relative+to+Population=true&Align+outbreaks=false&country=BEL~BGR~HRV~AUT~CZE~CYP~DNK~EST~FIN~FRA~DEU~GRC~HUN~IRL~ITA~LVA~LTU~LUX~MLT~NLD~POL~PRT~ROU~SVK~SVN~ESP~SWE) on 15th December 2021.

# %% [markdown]
# <img src="img/confirmed_cases.png" width="900"/>

# %% [markdown]
# - From this chart we can see that confirmed cases first began January 24th 2020. This related to the first EU case confirmed in France.

# %% [markdown]
# - We can see the curve beginning to take shape around mid March which is when th WHO declared a global pandemic.

# %% [markdown]
# - However, the curve is still quite flat which has a clear link with many of the EU countries implementing public health restrictions. For example, regional and national lockdowns, social distancing, face mask wearing, travel restrictions, remote working and learning.

# %% [markdown]
# - Next we see a rise beginning around August 2020. This coincides when the end of the summer months where outdoor dinning and socialising may start to decrease due to the weather. Therefore, it is fair to say there is a direct connection between the season of the year and outdoor hospitality.

# %% [markdown]
# - The rise continues through September and October 2020 which is when the ECDC reported an increase in confirmed covid-19 cases across Europe.

# %% [markdown]
# - Furthermore, we an see a spike in Novemebr 2020. Most EU countries eased restrictions on the lead up to the Christmas Holidays. However, there is another factor to consider here. The discovery of a new varient of covid-19 called "Alpha". The first case of this was documented in the UK in September 2020. The UK offically left he EU in December 31st 2020. Therefore, it is fair to say that the travel agreement between EU states included the UK at this point and therefore enabled the spread of this varient.

# %% [markdown]
# - Moreover, there is a continued rise in confirmed cases up until April 2021. This may be impacted by another covid-19 varient "Gamma" spreading worldwide. However, we can see the curve levelling off which may have two factors.
#
#     1. Change of seasons again when the EU enters into spring/summer.
#
#     2. The implementation of vaccinations across the EU.

# %% [markdown]
# - We can see most countries maintain their level of covid-19 cases from June 2021 up until September 2021. This may again be due to the weather and available of outdoor socialisation but also the vaccination rollout.

# %% [markdown]
# - However, we can see a increase beginning around Septemeber 2021 which coinsides with the ECDC urging EU citizens to get vaccinated.

# %% [markdown]
# - This rise is continuing to rise into December 2021. This may also be impacted by another new varient of covid-19; "omicron". This was first noted in Novemeber 2021 and appears to spread rapidly.

# %% [markdown]
# ## Reported covid retaled deaths

# %% [markdown]
# Considering the same EU member states let's look at this chart contraining the cumulative confirmed deaths of covid-19 from the beginning of the pandemic. This chart can be found [here](https://ourworldindata.org/explorers/coronavirus-data-explorer?time=earliest..2021-12-16&facet=none&uniformYAxis=0&pickerSort=asc&pickerMetric=location&Metric=Confirmed+deaths&Interval=Cumulative&Relative+to+Population=true&Align+outbreaks=false&country=BEL~BGR~HRV~AUT~CZE~CYP~DNK~EST~FIN~FRA~DEU~GRC~HUN~IRL~ITA~LVA~LTU~LUX~MLT~NLD~POL~PRT~ROU~SVK~SVN~ESP~SWE). The below image was taken from our world in data webpage on December 15th 2021.

# %% [markdown]
# <img src="img/confirmed_deaths.png" width="900"/>

# %% [markdown]
# - We can see here that the first reported death from covid-19 was on February 15th 2020 in France.

# %% [markdown]
# - Then there appears to be a rapid increase from Italy which coincides with the outbreak reported in the ECDC timeline.

# %% [markdown]
# - This increase seems to level off until around November 2020. This may be due to some countries implementing travel and public health restictions.

# %% [markdown]
# - Interestingly, the death count begins to rise in October/Novemer 2020 which has a link to the rise in cases reported by the ECDC at this time also. It may also be impacted by the "Alpha" varient of covid-19 which was first noted in the EK in September 2020.

# %% [markdown]
# - This increase continues through December 2020 up until April 2021. This coincides with the rise in cases at this time also.

# %% [markdown]
# - Next we see the death toll levelling off for most countries from April up until around October 2021. This may be due to the the

# %% [markdown]
# - There appears to be a rise in the confirmed deaths in November 2021 which may be linked to the new omicrom varient of covid-19.

# %% [markdown]
# - Furthermore, the death count is continuing to rise as of Decemebr 2021 which is accurate given the current rise in cases.

# %% [markdown]
# ## Percentage of population fully vaccinated

# %% [markdown]
# This image gives a linear overview of the percentage of each countries' population that is fully vaccinated. This our world in data chart can be found [here](https://ourworldindata.org/explorers/coronavirus-data-explorer?time=earliest..2021-12-16&facet=none&uniformYAxis=0&pickerSort=asc&pickerMetric=location&Metric=People+fully+vaccinated&Interval=Cumulative&Relative+to+Population=true&Align+outbreaks=false&country=BEL~BGR~HRV~AUT~CZE~CYP~DNK~EST~FIN~FRA~DEU~GRC~HUN~IRL~ITA~LVA~LTU~LUX~MLT~NLD~POL~PRT~ROU~SVK~SVN~ESP~SWE).

# %% [markdown]
# <img src="img/fully_vaccinated.png" width="900"/>

# %% [markdown]
# From this chart we can see the first dose was administered Dec 27th 2020 following the ECDC authorization and vaccination strategy. We can see a gradual rise in vaccinated people.

# %% [markdown]
# We can see from the following horizontal bar chart found [here](https://ourworldindata.org/explorers/coronavirus-data-explorer?time=2020-12-27&facet=none&uniformYAxis=0&pickerSort=asc&pickerMetric=location&Metric=People+fully+vaccinated&Interval=Cumulative&Relative+to+Population=true&Align+outbreaks=false&country=BEL~BGR~HRV~AUT~CZE~CYP~DNK~EST~FIN~FRA~DEU~GRC~HUN~IRL~ITA~LVA~LTU~LUX~MLT~NLD~POL~PRT~ROU~SVK~SVN~ESP~SWE) Denmark had the highest percetage of their population fully vaccinated by January 31st 2021 at only 1.42%. Slovenia, Italy and Ireland follow closely with over 1% of their population fully vaccinated.

# %% [markdown]
# <img src="img/fully_vaccinated_jan2021.png" width="900"/>

# %% [markdown]
# There are a number of factors that need to be considered here.
#
#    1. Supply vs demand. The vaccine was only approved by the ECDC in December 2020. Therefore, there would be a time delay for production and delivery. And it would depend on how many doese were distributed to each country and when.
#
#    2. All vaccines except for the Janssen vaccines require two doses before a person is fully vaccinated. Therefore, it is fair to say that it is unlikely that more than 1% of a country's population would be fully vaccinated in just one month.

# %% [markdown]
# If we look at the below image showing figures from July 1st 2021, just 6 months later we can see a huge difference in the percentage of population fully vaccinated.

# %% [markdown]
# <img src="img/fully_vaccinated_jul2021.png" width="900"/>

# %% [markdown]
# We can see here that Malta is leading the vaccination process with 42.3% of it's population fully vaccinated. However, if we compare the population of Malta to the poplation of Germany there is a huge difference. Therefore it is no surprise that Malta is leading the race as it has fewer citizens to vaccinate.

# %% [markdown]
# Let's have a look at the population of the EU member states found on [wikipedia](https://en.wikipedia.org/wiki/List_of_European_Union_member_states_by_population) on December 15th 2021.

# %% [markdown]
# <img src="img/eu_population.png" width="900"/>

# %% [markdown]
# From this table we can see that Malta has the lowest population out of all the EU member states at under 515,000 people. Whereas Germany has over 83 million people. That's over 160 times the amount of Malta.

# %% [markdown]
# With this in mind it is fair to say Germany is doing well in terms of vaccination rollout with 18.84% of it's population fully vaccinated as of June 1st 2021.

# %% [markdown]
# In contrast to this we can see Hungary has 38.35% of it's population of almost 10 million fully vaccinated. Hungary has about 18 times more people to vaccinated than Malta, however it is in second place in the vaccination race. Therefore, it could be concluded that the Hungarian government has an efficent vaccination stragegy in place.

# %% [markdown]
# If we look at the current percentages on Decevmber 14th 2021 in the image below, we can see that almost half of EU member states have 70% of their population fully vaccinated against covid-19.

# %% [markdown]
# <img src="img/fully_vaccinated_dec2021.png" width="900"/>

# %% [markdown]
# However, it is alarming to see that Bulgaria with almost 7 million people has only 26.84% fully vaccinated. Furthermore, Romania has only 40.09% of it's 19 million people fully vaccinated. Moreover, Poland has almost 38 million citizens with only 54.85% fully vaccinated. There is an alarming difference if we compare Poland to Spain which has over 47 million people and has 80.77% fully vaccinated. Spain has a larger population and a higher percentage of that population fully vaccinated against covid-19.
#
#
# These figures would explain why the ECDC has been promoting and urging EU citizens since August 2021 to get vaccinated. Some reasons for lack of vaccination may be casued by misleading information. The EU commission began a campagin to fight disinformation in March 2020. A link to this campagin can be found [here](https://ec.europa.eu/info/live-work-travel-eu/coronavirus-response/fighting-disinformation_en). The main topic is seperating fact from fiction. Individual EU countries also started their own campagins to urge their citizens to get vaccinated.

# %% [markdown]
# ## Percentage of polulation partially vaccinated

# %% [markdown]
# ## Percentage of population unvaccinated

# %% [markdown]
# # Relationship between variables
# ***

# %% [markdown]
# ### cases vs deaths

# %% [markdown]
# ### cases vs population

# %% [markdown]
# ### vaccinated vs partially vs unvaccinated

# %% [markdown]
# ### vaccinated vs cases

# %% [markdown]
# ### unvaccinated vs cases

# %% [markdown]
# ### unvaccinated vs deaths

# %% [markdown]
# ### unvaccinated vs cases

# %% [markdown]
# # Simulate Data using Pandas
# ***

# %% [markdown]
# #### Detail your research and implement the simulation in a Jupyter notebook – the data set itself can simply be displayed in an output cell within the notebook.
#
# #### Synthesise/simulate a data set as closely matching their properties as possible

# %% [markdown]
# ## Importing Modules
# ***

# %%
# For dataframes.
import pandas as pd

# For numerical arrays. 
import numpy as np

# For plotting.
import matplotlib.pyplot as plt

# %% [markdown]
# ## Design & Style
# ***

# %%
# Using magic command to set plots to display inline.
# %matplotlib inline

# Setting plot style. 
plt.style.use('fivethirtyeight')

# Set figure size. 
plt.rcParams['figure.figsize'] = [18, 14]

# %% [markdown]
# ### referneces for end
# https://stackoverflow.com/questions/20167930/start-index-at-1-for-pandas-dataframe/20168416
#
# population as per 13dec from https://en.wikipedia.org/wiki/Demographics_of_the_European_Union
#
# vaccinated as per 13dec from https://ourworldindata.org/explorers/coronavirus-data-explorer?tab=table&facet=none&pickerSort=asc&pickerMetric=location&Metric=People+fully+vaccinated&Interval=7-day+rolling+average&Relative+to+Population=true&Align+outbreaks=false&country=~AUT
#
# deaths as of 14dec https://ourworldindata.org/coronavirus-data
#
# type of vaccines ireland https://covid-19.geohive.ie/pages/vaccinations

# %% [markdown]
# ## The Dataframe
# ***

# %%
country = {'country':['Austria', 'Belgium', 'Bulgaria', 'Croatia', 'Cyprus', 'Czech Republic', 'Denmark',
           'Estonia', 'Finland', 'France', 'Germany', 'Greece', 'Hungary', 'Ireland', 'Italy', 'Latvia',
           'Lithuania', 'Luxembourg', 'Malta', 'Netherlands', 'Poland', 'Portugal', 'Romania', 'Slovakia',
           'Slovenia', 'Spain', 'Sweden']}

# Load data to df.
df = pd.DataFrame(country)
# Name column.
df.columns = ['country']
# Set index to start at 1. 
df.index = np.arange(1, len(df)+1)
df
# Out:
#            country
# 1          Austria
# 2          Belgium
# 3         Bulgaria
# 4          Croatia
# 5           Cyprus
# 6   Czech Republic
# 7          Denmark
# 8          Estonia
# 9          Finland
# 10          France
# 11         Germany
# 12          Greece
# 13         Hungary
# 14         Ireland
# 15           Italy
# 16          Latvia
# 17       Lithuania
# 18      Luxembourg
# 19           Malta
# 20     Netherlands
# 21          Poland
# 22        Portugal
# 23         Romania
# 24        Slovakia
# 25        Slovenia
# 26           Spain
# 27          Sweden

# %%
# Setting inital start point to generate same random numbers. 
np.random.seed(1000)

# Creating random integers and floats. 
data = {'popultion': np.random.randint(470000, 83000000, 27), 
        'reported_cases': np.random.randint(40624, 400000, 27),
        'reported_deaths': np.random.randint(471, 135000, 27),
        'fully_vaccinated': np.around(np.random.uniform(26.67, 88.81, 27), 2),
        'partially_vaccinated': np.around(np.random.uniform(0.21, 6.28, 27), 2)}
    
# Inputting data into df2. 
df2 = pd.DataFrame(data)
# Setting column names. 
df2.columns = ['population', 'reported_cases', 'reported_deaths', 'fully_vaccinated',
              'partially_vaccinated']
# Setting same index as df.
df2.index = np.arange(1, len(df2)+1)
df2
# Out:
#     population  reported_cases  reported_deaths  fully_vaccinated  \
# 1     77872711          301136           108393             33.37
# 2     71908016          348642            49625             46.33
# 3     55372011           61381            45202             52.12
# 4     44528974          374730            31425             69.37
# 5     58200396          388884             4218             70.31
# 6     73707249          156343           127640             54.40
# 7     27265648           61248            72560             52.79
# 8     58866205          289700           101288             76.55
# 9     41098776           57863           124063             60.14
# 10     2573145           83980            52057             84.06
# 11    62241044          103259            80802             30.52
# 12    34817708          397857            42656             49.51
# 13    51238367          138603            17892             86.97
# 14     2190548          237007            23190             70.11
# 15    74146436          369218            84586             82.04
# 16    30887310           41905            17888             42.43
# 17    21083020          322747            43741             71.75
# 18    44867982           57694           100265             39.32
# 19    65514685          150091           133952             60.07
# 20    50679490          251615           128044             41.39
# 21    39901901          155271             2191             53.79
# 22    10400890           90111           100877             76.26
# 23    34081278          322165            60589             45.83
# 24    57496365           58044           116786             65.29
# 25    16898613          370475            41133             53.99
# 26    82878372          176392            70602             83.42
# 27    34618171          279672            33311             67.60
#
#     partially_vaccinated
# 1                   4.18
# 2                   2.39
# 3                   3.38
# 4                   0.48
# 5                   0.78
# 6                   5.80
# 7                   0.65
# 8                   5.85
# 9                   4.56
# 10                  3.99
# 11                  4.79
# 12                  1.07
# 13                  5.03
# 14                  4.61
# 15                  3.50
# 16                  3.14
# 17                  3.10
# 18                  2.92
# 19                  5.16
# 20                  1.88
# 21                  0.59
# 22                  6.04
# 23                  2.99
# 24                  4.81
# 25                  4.34
# 26                  3.50
# 27                  1.02

# %%
# Joining df2 to df.
df = df.join(df2)
df
# Out:
#            country  population  reported_cases  reported_deaths  \
# 1          Austria    77872711          301136           108393
# 2          Belgium    71908016          348642            49625
# 3         Bulgaria    55372011           61381            45202
# 4          Croatia    44528974          374730            31425
# 5           Cyprus    58200396          388884             4218
# 6   Czech Republic    73707249          156343           127640
# 7          Denmark    27265648           61248            72560
# 8          Estonia    58866205          289700           101288
# 9          Finland    41098776           57863           124063
# 10          France     2573145           83980            52057
# 11         Germany    62241044          103259            80802
# 12          Greece    34817708          397857            42656
# 13         Hungary    51238367          138603            17892
# 14         Ireland     2190548          237007            23190
# 15           Italy    74146436          369218            84586
# 16          Latvia    30887310           41905            17888
# 17       Lithuania    21083020          322747            43741
# 18      Luxembourg    44867982           57694           100265
# 19           Malta    65514685          150091           133952
# 20     Netherlands    50679490          251615           128044
# 21          Poland    39901901          155271             2191
# 22        Portugal    10400890           90111           100877
# 23         Romania    34081278          322165            60589
# 24        Slovakia    57496365           58044           116786
# 25        Slovenia    16898613          370475            41133
# 26           Spain    82878372          176392            70602
# 27          Sweden    34618171          279672            33311
#
#     fully_vaccinated  partially_vaccinated
# 1              33.37                  4.18
# 2              46.33                  2.39
# 3              52.12                  3.38
# 4              69.37                  0.48
# 5              70.31                  0.78
# 6              54.40                  5.80
# 7              52.79                  0.65
# 8              76.55                  5.85
# 9              60.14                  4.56
# 10             84.06                  3.99
# 11             30.52                  4.79
# 12             49.51                  1.07
# 13             86.97                  5.03
# 14             70.11                  4.61
# 15             82.04                  3.50
# 16             42.43                  3.14
# 17             71.75                  3.10
# 18             39.32                  2.92
# 19             60.07                  5.16
# 20             41.39                  1.88
# 21             53.79                  0.59
# 22             76.26                  6.04
# 23             45.83                  2.99
# 24             65.29                  4.81
# 25             53.99                  4.34
# 26             83.42                  3.50
# 27             67.60                  1.02

# %%
# using np function to subtract one array from another. 
unvaccinated = np.subtract(df2['fully_vaccinated'], df2['partially_vaccinated'])

# Load df3. 
df3 = pd.DataFrame(unvaccinated)
# Setting column name. 
df3.columns = ['unvaccinated']
# Set same index again.
df3.index = np.arange(1, len(df3)+1)

# %%
df = df.join(df3)

# %%
cases_percentage = np.divide( df2['reported_cases'],df2['population'])
cases_percentage = np.around((np.multiply(cases_percentage, 100)), 2)

# Load df4. 
df4 = pd.DataFrame(cases_percentage)
# Setting column name. 
df4.columns = ['cases_percentage']
# Set same index again.
df4.index = np.arange(1, len(df4)+1)

# %%
df = df.join(df4)

# %%
death_percentage = np.divide( df2['reported_deaths'],df2['population'])
death_percentage = np.around((np.multiply(death_percentage, 100)), 2)

# Load df5. 
df5 = pd.DataFrame(death_percentage)
# Setting column name. 
df5.columns = ['death_percentage']
# Set same index again.
df5.index = np.arange(1, len(df4)+1)

# %%
df = df.join(df5)

# %%
df
# Out:
#            country  population  reported_cases  reported_deaths  \
# 1          Austria    77872711          301136           108393
# 2          Belgium    71908016          348642            49625
# 3         Bulgaria    55372011           61381            45202
# 4          Croatia    44528974          374730            31425
# 5           Cyprus    58200396          388884             4218
# 6   Czech Republic    73707249          156343           127640
# 7          Denmark    27265648           61248            72560
# 8          Estonia    58866205          289700           101288
# 9          Finland    41098776           57863           124063
# 10          France     2573145           83980            52057
# 11         Germany    62241044          103259            80802
# 12          Greece    34817708          397857            42656
# 13         Hungary    51238367          138603            17892
# 14         Ireland     2190548          237007            23190
# 15           Italy    74146436          369218            84586
# 16          Latvia    30887310           41905            17888
# 17       Lithuania    21083020          322747            43741
# 18      Luxembourg    44867982           57694           100265
# 19           Malta    65514685          150091           133952
# 20     Netherlands    50679490          251615           128044
# 21          Poland    39901901          155271             2191
# 22        Portugal    10400890           90111           100877
# 23         Romania    34081278          322165            60589
# 24        Slovakia    57496365           58044           116786
# 25        Slovenia    16898613          370475            41133
# 26           Spain    82878372          176392            70602
# 27          Sweden    34618171          279672            33311
#
#     fully_vaccinated  partially_vaccinated  unvaccinated  cases_percentage  \
# 1              33.37                  4.18         29.19              0.39
# 2              46.33                  2.39         43.94              0.48
# 3              52.12                  3.38         48.74              0.11
# 4              69.37                  0.48         68.89              0.84
# 5              70.31                  0.78         69.53              0.67
# 6              54.40                  5.80         48.60              0.21
# 7              52.79                  0.65         52.14              0.22
# 8              76.55                  5.85         70.70              0.49
# 9              60.14                  4.56         55.58              0.14
# 10             84.06                  3.99         80.07              3.26
# 11             30.52                  4.79         25.73              0.17
# 12             49.51                  1.07         48.44              1.14
# 13             86.97                  5.03         81.94              0.27
# 14             70.11                  4.61         65.50             10.82
# 15             82.04                  3.50         78.54              0.50
# 16             42.43                  3.14         39.29              0.14
# 17             71.75                  3.10         68.65              1.53
# 18             39.32                  2.92         36.40              0.13
# 19             60.07                  5.16         54.91              0.23
# 20             41.39                  1.88         39.51              0.50
# 21             53.79                  0.59         53.20              0.39
# 22             76.26                  6.04         70.22              0.87
# 23             45.83                  2.99         42.84              0.95
# 24             65.29                  4.81         60.48              0.10
# 25             53.99                  4.34         49.65              2.19
# 26             83.42                  3.50         79.92              0.21
# 27             67.60                  1.02         66.58              0.81
#
#     death_percentage
# 1               0.14
# 2               0.07
# 3               0.08
# 4               0.07
# 5               0.01
# 6               0.17
# 7               0.27
# 8               0.17
# 9               0.30
# 10              2.02
# 11              0.13
# 12              0.12
# 13              0.03
# 14              1.06
# 15              0.11
# 16              0.06
# 17              0.21
# 18              0.22
# 19              0.20
# 20              0.25
# 21              0.01
# 22              0.97
# 23              0.18
# 24              0.20
# 25              0.24
# 26              0.09
# 27              0.10

# %% [markdown]
# ## MIGHT USE AT END
# ***

# %%
'''
df.plot.barh(x='country', y=['fully_vaccinated', 'partially_vaccinated', 'unvaccinated'], width=0.65)
plt.gca().invert_yaxis()
plt.xlabel('Percentage of Population')
plt.ylabel('Countries')
plt.title('Vaccination Percentages of European Union')
plt.show()
'''
# Out:
# "\ndf.plot.barh(x='country', y=['fully_vaccinated', 'partially_vaccinated', 'unvaccinated'], width=0.65)\nplt.gca().invert_yaxis()\nplt.xlabel('Percentage of Population')\nplt.ylabel('Countries')\nplt.title('Vaccination Percentages of European Union')\nplt.show()\n"

# %%
# ACTUAL DATA COLLECT DEC 13TH 2021
'''
# Creating data for df columns. 
dta = {'country':['Austria', 'Belgium', 'Bulgaria', 'Croatia', 'Cyprus', 'Czech Republic', 'Denmark',
           'Estonia', 'Finland', 'France', 'Germany', 'Greece', 'Hungary', 'Ireland', 'Italy', 'Latvia',
           'Lithuania', 'Luxembourg', 'Malta', 'Netherlands', 'Poland', 'Portugal', 'Romania', 'Slovakia',
           'Slovenia', 'Spain', 'Sweden'],
        'population':[8772865, 11351727, 7101859, 4154213, 854802, 10578820, 5748769, 1315635, 5503297, 
                      66989083, 82521653, 10768193, 9797561, 4904226, 60589445, 1950116, 2847904, 590667, 
                      467988, 17081507, 37972964, 10309573, 19644350, 5435343, 2065895, 46528966, 9995153],
        'reported_cases':[1230000, 1960000, 714688, 654655, 141566, 2340000, 568477, 228596, 205357, 8360000, 
                          6580000, 1010000, 120000, 628306, 5240000, 262215, 491953, 94300, 40624, 2940000, 
                          3840000, 120000, 1790000, 1290000, 440633, 5340000, 1230000],
        'reported_deaths':[13218, 27631, 29536, 11666, 611, 34551, 3023, 1865, 1442, 121000, 106000, 19345, 36884,
                       5788, 135000, 4376, 6989, 895, 471, 20140, 88508, 18673, 57741, 15415, 5425, 88484, 15191],
        'fully_vaccinated':[68.38, 75.06, 26.67, 49.92, 65.88, 60.49, 77.18, 60.50, 73.56, 70.80, 68.99, 65.21, 
                      61.17, 76.43, 73.37, 65.78, 67.06, 67.69, 84.08, 74.37, 54.73, 88.81, 39.88, 43.32,
                      56.30, 80.66, 71.46],
        'partially_vaccinated':[3.11, 1.09, 0.80, 4.60, 4.53, 2.28, 3.00, 2.38, 4.29, 6.28, 3.01, 4.74, 3.03, 1.23,
                                5.53, 3.36, 3.19, 2.51, 0.58, 2.93, 1.29, 0.21, 1.43, 5.69, 3.23, 1.70, 3.96],
       'unvaccinated':[28.51, 23.85, 72.53, 45.48, 29.59, 37.23, 19.82, 37.12, 22.15, 22.92, 28.00, 30.05, 
                        35.80, 22.34, 21.10, 30.86, 29.75, 29.80, 15.34, 22.70, 43.98, 10.98, 58.69, 50.99, 
                        40.47, 17.64, 24.58]}

# Inputting data into df. 
dff = pd.DataFrame(dta)
# Setting column names. 
dff.columns = ['country', 'population', 'reported_cases', 'reported_deaths', 'fully_vaccinated', 
              'partially_vaccinated', 'unvaccinated']
# Setting index to np array starting at 1. 
dff.index = np.arange(1, len(dff)+1)
#df.set_index('country', inplace=True)
dff
'''
# Out:
# "\n# Creating data for df columns. \ndta = {'country':['Austria', 'Belgium', 'Bulgaria', 'Croatia', 'Cyprus', 'Czech Republic', 'Denmark',\n           'Estonia', 'Finland', 'France', 'Germany', 'Greece', 'Hungary', 'Ireland', 'Italy', 'Latvia',\n           'Lithuania', 'Luxembourg', 'Malta', 'Netherlands', 'Poland', 'Portugal', 'Romania', 'Slovakia',\n           'Slovenia', 'Spain', 'Sweden'],\n        'population':[8772865, 11351727, 7101859, 4154213, 854802, 10578820, 5748769, 1315635, 5503297, \n                      66989083, 82521653, 10768193, 9797561, 4904226, 60589445, 1950116, 2847904, 590667, \n                      467988, 17081507, 37972964, 10309573, 19644350, 5435343, 2065895, 46528966, 9995153],\n        'reported_cases':[1230000, 1960000, 714688, 654655, 141566, 2340000, 568477, 228596, 205357, 8360000, \n                          6580000, 1010000, 120000, 628306, 5240000, 262215, 491953, 94300, 40624, 2940000, \n                          3840000, 120000, 1790000, 1290000, 440633, 5340000, 1230000],\n        'reported_deaths':[13218, 27631, 29536, 11666, 611, 34551, 3023, 1865, 1442, 121000, 106000, 19345, 36884,\n                       5788, 135000, 4376, 6989, 895, 471, 20140, 88508, 18673, 57741, 15415, 5425, 88484, 15191],\n        'fully_vaccinated':[68.38, 75.06, 26.67, 49.92, 65.88, 60.49, 77.18, 60.50, 73.56, 70.80, 68.99, 65.21, \n                      61.17, 76.43, 73.37, 65.78, 67.06, 67.69, 84.08, 74.37, 54.73, 88.81, 39.88, 43.32,\n                      56.30, 80.66, 71.46],\n        'partially_vaccinated':[3.11, 1.09, 0.80, 4.60, 4.53, 2.28, 3.00, 2.38, 4.29, 6.28, 3.01, 4.74, 3.03, 1.23,\n                                5.53, 3.36, 3.19, 2.51, 0.58, 2.93, 1.29, 0.21, 1.43, 5.69, 3.23, 1.70, 3.96],\n       'unvaccinated':[28.51, 23.85, 72.53, 45.48, 29.59, 37.23, 19.82, 37.12, 22.15, 22.92, 28.00, 30.05, \n                        35.80, 22.34, 21.10, 30.86, 29.75, 29.80, 15.34, 22.70, 43.98, 10.98, 58.69, 50.99, \n                        40.47, 17.64, 24.58]}\n\n# Inputting data into df. \ndff = pd.DataFrame(dta)\n# Setting column names. \ndff.columns = ['country', 'population', 'reported_cases', 'reported_deaths', 'fully_vaccinated', \n              'partially_vaccinated', 'unvaccinated']\n# Setting index to np array starting at 1. \ndff.index = np.arange(1, len(dff)+1)\n#df.set_index('country', inplace=True)\ndff\n"

# %% [markdown]
# # Conclusion

# %% [markdown]
# # References
# ***
# All references and code used in this notebook has been sourced in Dec 2021 from the following webpages:
#
#
# -
#
#
# -

# %% [markdown]
# ***
# # End
